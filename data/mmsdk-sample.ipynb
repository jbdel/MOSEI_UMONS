# %% [markdown]
# <a href="https://colab.research.google.com/github/ShengruiLYU/MOSEI_UMONS/blob/master/data/mmsdk-sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MMML First Assignment
#
# Examples of how to use CMU Multimodal SDK

# %%
# !git clone https://github.com/A2Zadeh/CMU-MultimodalSDK
# !pip install h5py validators tqdm numpy argparse requests colorama

# %%
import os
os.chdir('/content/CMU-MultimodalSDK')
from mmsdk import mmdatasdk

# %%
# the first time we use it: download from web to a local destination ./cmu-mosei/
# this will take nearly 1 hour
cmumosei_highlevel = mmdatasdk.mmdataset(mmdatasdk.cmu_mosei.highlevel, 'cmu-mosei/')
# Out:
#   0%|          | 0/1514432 [00:00<?, ?kB/s, Total in kBs]
# [2020-09-30 03:10:57.068] | Status  | Downloading from http://immortal.multicomp.cs.cmu.edu/CMU-MOSEI/language/CMU_MOSEI_TimestampedWordVectors.csd to cmu-mosei/CMU_MOSEI_TimestampedWordVectors.csd...
#   0%|          | 0/3837 [00:00<?, ? Computational Sequence Entries/s]
# [2020-09-30 03:13:00.830] | Success | Download complete!
# [2020-09-30 03:13:00.842] | Success | Computational sequence read from file cmu-mosei/CMU_MOSEI_TimestampedWordVectors.csd ...
# [2020-09-30 03:13:00.970] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2020-09-30 03:13:00.970] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2020-09-30 03:13:02.351] | Success | <glove_vectors> computational sequence data in correct format.
# [2020-09-30 03:13:02.351] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2020-09-30 03:13:02.351] | Success | <glove_vectors> computational sequence metadata in correct format.
# [2020-09-30 03:13:02.351] | Success | <glove_vectors> computational sequence is valid!
#   0%|          | 37/11314059 [00:00<8:29:47, 369.90kB/s, Total in kBs]
# [2020-09-30 03:13:02.616] | Status  | Downloading from http://immortal.multicomp.cs.cmu.edu/CMU-MOSEI/acoustic/CMU_MOSEI_COVAREP.csd to cmu-mosei/CMU_MOSEI_COVAREP.csd...
#   0%|          | 0/3836 [00:00<?, ? Computational Sequence Entries/s]
# [2020-09-30 03:30:26.141] | Success | Download complete!
# [2020-09-30 03:30:26.145] | Success | Computational sequence read from file cmu-mosei/CMU_MOSEI_COVAREP.csd ...
# [2020-09-30 03:30:26.282] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2020-09-30 03:30:26.282] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2020-09-30 03:30:27.644] | Success | <COVAREP> computational sequence data in correct format.
# [2020-09-30 03:30:27.644] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2020-09-30 03:30:27.644] | Success | <COVAREP> computational sequence metadata in correct format.
# [2020-09-30 03:30:27.645] | Success | <COVAREP> computational sequence is valid!
#   0%|          | 14/16326638 [00:00<32:23:41, 140.00kB/s, Total in kBs]
# [2020-09-30 03:30:27.926] | Status  | Downloading from http://immortal.multicomp.cs.cmu.edu/CMU-MOSEI/visual/CMU_MOSEI_VisualOpenFace2.csd to cmu-mosei/CMU_MOSEI_VisualOpenFace2.csd...
# [2020-09-30 03:58:17.234] | Success | Download complete!
# [2020-09-30 03:58:17.237] | Success | Computational sequence read from file cmu-mosei/CMU_MOSEI_VisualOpenFace2.csd ...
#   4%|▎         | 137/3837 [00:00<00:02, 1334.48 Computational Sequence Entries/s]
# [2020-09-30 03:58:18.120] | Status  | Checking the integrity of the <OpenFace_2> computational sequence ...
# [2020-09-30 03:58:18.120] | Status  | Checking the format of the data in <OpenFace_2> computational sequence ...
# [2020-09-30 03:58:20.468] | Success | <OpenFace_2> computational sequence data in correct format.
# [2020-09-30 03:58:20.468] | Status  | Checking the format of the metadata in <OpenFace_2> computational sequence ...
# [2020-09-30 03:58:20.468] | Success | <OpenFace_2> computational sequence metadata in correct format.
# [2020-09-30 03:58:20.468] | Success | <OpenFace_2> computational sequence is valid!
#   0%|          | 15/1617674 [00:00<2:59:44, 150.00kB/s, Total in kBs]
# [2020-09-30 03:58:20.918] | Status  | Downloading from http://immortal.multicomp.cs.cmu.edu/CMU-MOSEI/visual/CMU_MOSEI_VisualFacet42.csd to cmu-mosei/CMU_MOSEI_VisualFacet42.csd...
#   7%|▋         | 286/3837 [00:00<00:01, 2852.64 Computational Sequence Entries/s]
# [2020-09-30 04:01:09.234] | Success | Download complete!
# [2020-09-30 04:01:09.236] | Success | Computational sequence read from file cmu-mosei/CMU_MOSEI_VisualFacet42.csd ...
# [2020-09-30 04:01:09.337] | Status  | Checking the integrity of the <FACET 4.2> computational sequence ...
# [2020-09-30 04:01:09.337] | Status  | Checking the format of the data in <FACET 4.2> computational sequence ...
# [2020-09-30 04:01:10.665] | Success | <FACET 4.2> computational sequence data in correct format.
# [2020-09-30 04:01:10.665] | Status  | Checking the format of the metadata in <FACET 4.2> computational sequence ...
# [2020-09-30 04:01:10.665] | Success | <FACET 4.2> computational sequence metadata in correct format.
# [2020-09-30 04:01:10.665] | Success | <FACET 4.2> computational sequence is valid!
# [2020-09-30 04:01:10.665] | Success | Dataset initialized successfully ...

# %%
cmumosei_highlevel.keys() # available high-level features
# Out:
# dict_keys(['glove_vectors', 'COVAREP', 'OpenFace_2', 'FACET 4.2'])

# %%
openface = cmumosei_highlevel['OpenFace_2']
openface.keys() # source identifiers, e.g., video ID
# Out:
# dict_keys(['--qXJuDtHPw', '-3g5yACwYnA', '-3nNcZdcdvU', '-571d8cVauQ', '-6rXp3zJ3kc', '-9YyBTjo1zo', '-9y-fZ3swSY', '-AUZQgSxyPQ', '-Alixo7euuU', '-Eqdz5y4pEY', '-HeZS2-Prhc', '-HvKLjmsO5U', '-HwX2H8Z4hY', '-IUUR2yyNbw', '-I_e4mIh0yE', '-IqSFQePnpU', '-KCahx2qBOI', '-LnuDPiuuZw', '-MeTTeMJBNc', '-NFrJFQijFE', '-RfYyzHpjk4', '-RpZEe4w4fY', '-SYSVSQnTnA', '-THoVjtIkeU', '-UUCSKoHeMA', '-UacrmKiTn4', '-UuX1xuaiiE', '-VmheDA92mM', '-WXXTNIJcVM', '-ZgjBOA1Yhw', '-a55Q6RWvTA', '-aNfi7CP8vM', '-aqamKhZ1Ec', '-bl5PfNIYr
'131936', '132028', '132476', '132570', '133201', '133888', '134252', '134298', '135623', '135658', '136196', '136205', '136211', '136215', '136234', '136416', '136647', '137455', '137827', '137920', '139006', '139032', '13JpsLvddoY', '140293', '140315', '140317', '154449', '15837', '158832', '158855', '159031', '15Wu4U2VPLw', '15ktF-6wutk', '160225', '16145', '16530', '167521', '172044', '172048', '172050', '172060', '172075', '173CpFb3clw', '17622', '176266', '176541', '17769', '17811', '178163', '17874', '178941', '179797', '179875', '180923', '180971', '181978', '183364', '184784', '186631', '186643', '187033', '187566', '187775', '188004', '188062', '188122', '188343', '188815', '188825', '18938', '189856', '189966', '18JTkk8JbeU', '18QjfdhJEM4', '190599', '190726', '190740', '190743', '191616', '191941', '19 ...

# %%
# inspect features of a sample (a 2-D array)
# 'intervals' is the associated timestamps
openface_sample = openface['--qXJuDtHPw']
print(openface_sample['features'])
print(openface_sample['intervals'])
# Out:
# <HDF5 dataset "features": shape (1714, 713), type "<f4">
# <HDF5 dataset "intervals": shape (1714, 2), type "<f8">

# %%
# exact numbers in the features can be retrieved using slicing similar to numpy
# see h5py documentation on datasets: https://docs.h5py.org/en/stable/high/dataset.html#dataset
openface_sample['intervals'][0]
# Out:
# array([0.   , 0.033])

# %%
# second time we use it: load data from local csd files
cmumosei_highlevel_from_file = mmdatasdk.mmdataset('cmu-mosei/')
# Out:
#   0%|          | 0/3837 [00:00<?, ? Computational Sequence Entries/s]
# [2020-09-30 05:26:11.002] | Success | Computational sequence read from file cmu-mosei/CMU_MOSEI_VisualFacet42.csd ...
# [2020-09-30 05:26:11.224] | Status  | Checking the integrity of the <FACET 4.2> computational sequence ...
# [2020-09-30 05:26:11.224] | Status  | Checking the format of the data in <FACET 4.2> computational sequence ...
# [2020-09-30 05:26:12.886] | Success | <FACET 4.2> computational sequence data in correct format.
# [2020-09-30 05:26:12.886] | Status  | Checking the format of the metadata in <FACET 4.2> computational sequence ...
# [2020-09-30 05:26:12.886] | Success | <FACET 4.2> computational sequence metadata in correct format.
# [2020-09-30 05:26:12.886] | Success | <FACET 4.2> computational sequence is valid!
# [2020-09-30 05:26:12.887] | Success | Computational sequence read from file cmu-mosei/CMU_MOSEI_VisualOpenFace2.csd ...
#   4%|▍         | 147/3837 [00:00<00:02, 1466.26 Computational Sequence Entries/s]
# [2020-09-30 05:26:13.096] | Status  | Checking the integrity of the <OpenFace_2> computational sequence ...
# [2020-09-30 05:26:13.096] | Status  | Checking the format of the data in <OpenFace_2> computational sequence ...
# [2020-09-30 05:26:15.307] | Success | <OpenFace_2> computational sequence data in correct format.
# [2020-09-30 05:26:15.307] | Status  | Checking the format of the metadata in <OpenFace_2> computational sequence ...
# [2020-09-30 05:26:15.307] | Success | <OpenFace_2> computational sequence metadata in correct format.
# [2020-09-30 05:26:15.307] | Success | <OpenFace_2> computational sequence is valid!
# [2020-09-30 05:26:15.309] | Success | Computational sequence read from file cmu-mosei/CMU_MOSEI_COVAREP.csd ...
#   1%|▏         | 51/3836 [00:00<00:07, 508.01 Computational Sequence Entries/s]
# [2020-09-30 05:26:15.753] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2020-09-30 05:26:15.753] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
#   0%|          | 0/3837 [00:00<?, ? Computational Sequence Entries/s]
# [2020-09-30 05:26:21.568] | Success | <COVAREP> computational sequence data in correct format.
# [2020-09-30 05:26:21.568] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2020-09-30 05:26:21.568] | Success | <COVAREP> computational sequence metadata in correct format.
# [2020-09-30 05:26:21.568] | Success | <COVAREP> computational sequence is valid!
# [2020-09-30 05:26:21.568] | Success | Computational sequence read from file cmu-mosei/CMU_MOSEI_TimestampedWordVectors.csd ...
# [2020-09-30 05:26:21.785] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2020-09-30 05:26:21.785] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2020-09-30 05:26:31.435] | Success | <glove_vectors> computational sequence data in correct format.
# [2020-09-30 05:26:31.435] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2020-09-30 05:26:31.435] | Success | <glove_vectors> computational sequence metadata in correct format.
# [2020-09-30 05:26:31.435] | Success | <glove_vectors> computational sequence is valid!
# [2020-09-30 05:26:31.435] | Success | Dataset initialized successfully ...

# %%
facet = cmumosei_highlevel['FACET 4.2']
facet.keys()
# Out:
# dict_keys(['--qXJuDtHPw', '-3g5yACwYnA', '-3nNcZdcdvU', '-571d8cVauQ', '-6rXp3zJ3kc', '-9YyBTjo1zo', '-9y-fZ3swSY', '-AUZQgSxyPQ', '-Alixo7euuU', '-Eqdz5y4pEY', '-HeZS2-Prhc', '-HvKLjmsO5U', '-HwX2H8Z4hY', '-IUUR2yyNbw', '-I_e4mIh0yE', '-IqSFQePnpU', '-KCahx2qBOI', '-LnuDPiuuZw', '-MeTTeMJBNc', '-NFrJFQijFE', '-RfYyzHpjk4', '-RpZEe4w4fY', '-SYSVSQnTnA', '-THoVjtIkeU', '-UUCSKoHeMA', '-UacrmKiTn4', '-UuX1xuaiiE', '-VmheDA92mM', '-WXXTNIJcVM', '-ZgjBOA1Yhw', '-a55Q6RWvTA', '-aNfi7CP8vM', '-aqamKhZ1Ec', '-bl5PfNIYrk', '-cEhr0cQcDM', '-cmk6cfUeMs', '-dZ1TCboxcQ', '-dxfTGcXJoc', '-egA8-b7-3M', '-hPfPhUIzfA', '-hnBHBN8p5A', '-iRBcNs9oI8', '-l_53IwQoj0', '-lqc32Zpr7M', '-lzEya4AM_4', '-m9KtvCk_L8', '-mJ2ud6oKI8', '-mqbVkbCndg', '-o_667Ny7RM', '-qDkUB0GgYY', '-qMhGeJkp5o', '-ri04Z7vwnc', '-rxZxtG0xmY', '-s9qJ7ATP7w', '-t217m2on-s', '-tANM6ETl_M', '-tPCytz4rww', '-uywlfIYOS8', '-vxjVxOeScU', '-wMB_hJL-3o', '-wdUIwjDMfg', '-wny0OAz3g8', '-yRb-Jum7EQ', '03X1FwF6udc', '06st0Ez_E_I', '07Z16yRBFUQ', '08d4NTXkSxw', '0AA-wmk8WdA', '0AkGtPz